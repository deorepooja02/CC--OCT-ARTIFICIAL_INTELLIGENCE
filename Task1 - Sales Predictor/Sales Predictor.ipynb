# %% [markdown]
# Sales Predictor

# %%
import pandas as pd

# %%
dataset = pd.read_csv("CarSales_test.csv")

# %%
dataset.head()
# Out:
#    week_id       date  sessions  online_leads_actuals  test_drive_request  \
# 0       80   8/7/2018     24420                    61                  38
# 1       80   9/7/2018     28615                    49                  23
# 2       80  10/7/2018     33702                    85                  52
# 3       80  11/7/2018     28600                    89                  46
# 4       80  12/7/2018     28625                    76                  41
#
#    offer_request  total_configs_finished  keep_me_updated  dealer_locator
# 0             23                    2396                0            2464
# 1             26                    2713                0            3532
# 2             33                    3167                0            3752
# 3             43                    2792                0            3112
# 4             35                    2888                0            3383

# %%
dataset.tail()
# Out:
#     week_id        date  sessions  online_leads_actuals  test_drive_request  \
# 50       87  27/08/2018     26606                    67                  43
# 51       87  28/08/2018     21923                    94                  61
# 52       87  29/08/2018     21338                    83                  38
# 53       87  30/08/2018     20607                    78                  58
# 54       87  31/08/2018     18980                    72                  36
#
#     offer_request  total_configs_finished  keep_me_updated  dealer_locator
# 50             24                    2971                0            3351
# 51             33                    2993                1            3495
# 52             45                    2985                1            3266
# 53             20                    2802                0            3101
# 54             36                    2718                0            2886

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   week_id                 55 non-null     int64
#  1   date                    55 non-null     object
#  2   sessions                55 non-null     int64
#  3   online_leads_actuals    55 non-null     int64
#  4   test_drive_request      55 non-null     int64
#  5   offer_request           55 non-null     int64
#  6   total_configs_finished  55 non-null     int64
#  7   keep_me_updated         55 non-null     int64
#  8   dealer_locator          55 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 4.0+ KB

# %%
dataset.isnull()
# Out:
#     week_id   date  sessions  online_leads_actuals  test_drive_request  \
# 0     False  False     False                 False               False
# 1     False  False     False                 False               False
# 2     False  False     False                 False               False
# 3     False  False     False                 False               False
# 4     False  False     False                 False               False
# 5     False  False     False                 False               False
# 6     False  False     False                 False               False
# 7     False  False     False                 False               False
# 8     False  False     False                 False               False
# 9     False  False     False                 False               False
# 10    False  False     False                 False               False
# 11    False  False     False                 False               False
# ...

# %%
dataset.describe()
# Out:
#          week_id      sessions  online_leads_actuals  test_drive_request  \
# count  55.000000     55.000000             55.000000           55.000000
# mean   83.436364  28099.854545             69.036364           39.127273
# std     2.283302   2846.377525             13.210495           10.259692
# min    80.000000  18980.000000             35.000000           18.000000
# 25%    81.500000  26851.500000             61.000000           32.500000
# 50%    83.000000  28625.000000             70.000000           41.000000
# 75%    85.000000  29905.500000             78.500000           45.000000
# max    87.000000  33702.000000             94.000000           61.000000
#
#        offer_request  total_configs_finished  keep_me_updated  dealer_locator
# count      55.000000               55.000000        55.000000       55.000000
# mean       29.909091             3110.836364         0.181818     3397.745455
# std         7.178344              259.908657         0.474962      291.821116
# ...

# %%
dataset.count()
# Out:
# week_id                   55
# date                      55
# sessions                  55
# online_leads_actuals      55
# test_drive_request        55
# offer_request             55
# total_configs_finished    55
# keep_me_updated           55
# dealer_locator            55
# dtype: int64

# %%
dataset.dropna()
# Out:
#     week_id        date  sessions  online_leads_actuals  test_drive_request  \
# 0        80    8/7/2018     24420                    61                  38
# 1        80    9/7/2018     28615                    49                  23
# 2        80   10/7/2018     33702                    85                  52
# 3        80   11/7/2018     28600                    89                  46
# 4        80   12/7/2018     28625                    76                  41
# 5        80  13/07/2018     27500                    83                  41
# 6        80  14/07/2018     26579                    64                  32
# 7        81  15/07/2018     27350                    65                  27
# 8        81  16/07/2018     29641                    81                  43
# 9        81  17/07/2018     29649                    65                  36
# 10       81  18/07/2018     29634                    72                  36
# ...

# %%
dataset.isnull().sum()
# Out:
# week_id                   0
# date                      0
# sessions                  0
# online_leads_actuals      0
# test_drive_request        0
# offer_request             0
# total_configs_finished    0
# keep_me_updated           0
# dealer_locator            0
# dtype: int64

# %%
dataset.rank()
# Out:
#     week_id  date  sessions  online_leads_actuals  test_drive_request  \
# 0       4.0  52.0       6.0                  14.5                25.5
# 1       4.0  54.0      27.0                   4.5                 5.0
# 2       4.0   2.0      55.0                  49.5                50.0
# 3       4.0   4.0      26.0                  52.5                42.5
# 4       4.0   6.0      28.0                  37.5                30.0
# 5       4.0   8.0      19.0                  47.0                30.0
# 6       4.0  10.0      11.0                  17.5                13.0
# 7      11.0  12.0      17.0                  20.0                 7.0
# 8      11.0  14.0      39.0                  45.0                35.5
# 9      11.0  16.0      40.0                  20.0                22.5
# 10     11.0  18.0      38.0                  31.5                22.5
# 11     11.0  20.0      54.0                  11.0                19.0
# ...

# %%
dataset.min()
# Out:
# week_id                         80
# date                      1/8/2018
# sessions                     18980
# online_leads_actuals            35
# test_drive_request              18
# offer_request                   16
# total_configs_finished        2396
# keep_me_updated                  0
# dealer_locator                2464
# dtype: object

# %%
dataset.max()
# Out:
# week_id                         87
# date                      9/8/2018
# sessions                     33702
# online_leads_actuals            94
# test_drive_request              61
# offer_request                   45
# total_configs_finished        3840
# keep_me_updated                  2
# dealer_locator                3946
# dtype: object

# %%
dataset.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_12528/1799472221.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean()
# week_id                      83.436364
# sessions                  28099.854545
# online_leads_actuals         69.036364
# test_drive_request           39.127273
# offer_request                29.909091
# total_configs_finished     3110.836364
# keep_me_updated               0.181818
# dealer_locator             3397.745455
# dtype: float64

# %%
dataset.plot()
# Out:
# <AxesSubplot:>
